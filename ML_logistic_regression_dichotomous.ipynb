# %% [markdown]
# # Prepare dataset

# %% [markdown]
# ### Clear Solomon data

# %% [markdown]
# Convert all distant (2) & unclear (3) interactions to no-interaction (0) to ensure dichotomous outcome.

# %%
import pandas as pd

# List of dataset names
dataset_names = ['DYAD06NF', 'DYAD10NF', 'DYAD11NF', 'DYAD12NF', 'DYAD14NF',
                  'DYAD15NF', 'DYAD16NF', 'DYAD18NF', 'DYAD21NF', 'DYAD23NF', 'DYAD24NF'
                ]

# Base directory for input and output
input_dir = '/Users/ruzenkakaldenbach/Desktop/Behaviour/solomon/'
output_dir = '/Users/ruzenkakaldenbach/Desktop/Behaviour/solomon/'

# Process each dataset
for dat_name in dataset_names:
    print(f"Processing {dat_name}...")
    
    # Load the dataset
    file_path = f"{input_dir}solomon_{dat_name}.csv"
    df = pd.read_csv(file_path)
    
    # Replace `2` (distant) and `3` (unclear) with `0` (no interaction)
    df[['si_ry', 'si_by', 'si_rb']] = df[['si_ry', 'si_by', 'si_rb']].replace({2: 0, 3: 0})
    
    # Save the modified dataset
    output_file = f"{output_dir}solomon_{dat_name}_dichotomous.csv"
    df.to_csv(output_file, index=False)
    print(f"Saved processed file to {output_file}")

print("Processing complete.")
# Out:
# Processing DYAD06NF...
# Saved processed file to /Users/ruzenkakaldenbach/Desktop/Behaviour/solomon/solomon_DYAD06NF_dichotomous.csv
# Processing DYAD10NF...
# Saved processed file to /Users/ruzenkakaldenbach/Desktop/Behaviour/solomon/solomon_DYAD10NF_dichotomous.csv
# Processing DYAD11NF...
# Saved processed file to /Users/ruzenkakaldenbach/Desktop/Behaviour/solomon/solomon_DYAD11NF_dichotomous.csv
# Processing DYAD12NF...
# Saved processed file to /Users/ruzenkakaldenbach/Desktop/Behaviour/solomon/solomon_DYAD12NF_dichotomous.csv
# Processing DYAD14NF...
# Saved processed file to /Users/ruzenkakaldenbach/Desktop/Behaviour/solomon/solomon_DYAD14NF_dichotomous.csv
# Processing DYAD15NF...
# Saved processed file to /Users/ruzenkakaldenbach/Desktop/Behaviour/solomon/solomon_DYAD15NF_dichotomous.csv
# Processing DYAD16NF...
# Saved processed file to /Users/ruzenkakaldenbach/Desktop/Behaviour/solomon/solomon_DYAD16NF_dichotomous.csv
# Processing DYAD18NF...
# Saved processed file to /Users/ruzenkakaldenbach/Desktop/Behaviour/solomon/solomon_DYAD18NF_dichotomous.csv
# Processing DYAD21NF...
# Saved processed file to /Users/ruzenkakaldenbach/Desktop/Behaviour/solomon/solomon_DYAD21NF_dichotomous.csv
# Processing DYAD23NF...
# Saved processed file to /Users/ruzenkakaldenbach/Desktop/Behaviour/solomon/solomon_DYAD23NF_dichotomous.csv
# Processing DYAD24NF...
# Saved processed file to /Users/ruzenkakaldenbach/Desktop/Behaviour/solomon/solomon_DYAD24NF_dichotomous.csv
# Processing complete.

# %%
df
# Out:
#       frame_timestamp  si_ry  si_by  si_rb
# 0                0.00      0      0      0
# 1                0.25      0      0      0
# 2                0.50      0      0      0
# 3                0.75      0      0      0
# 4                1.00      0      0      0
# ...               ...    ...    ...    ...
# 2414           603.50      0      0      0
# 2415           603.75      0      0      0
# 2416           604.00      0      0      0
# 2417           604.25      0      0      0
# 2418           604.50      0      0      0
#
# [2419 rows x 4 columns]

# %% [markdown]
# ### Create a common dataset for Loopy and Solomon data

# %% [markdown]
# The resulting dataset will contain Loopy data as predictor (distance, angle, facing) and Solomon data as outcome (social interaction). All dyads will be listed one below the other. All spreadsheets will then be listed one below the other.

# %%
import pandas as pd
import numpy as np

# List of dataset names
dataset_names = ['DYAD06NF', 'DYAD10NF', 'DYAD11NF', 'DYAD12NF', 'DYAD14NF',
                  'DYAD15NF', 'DYAD16NF', 'DYAD18NF', 'DYAD21NF', 'DYAD23NF', 'DYAD24NF'
                ]

# Directories for input and output
solomon_dir = '/Users/ruzenkakaldenbach/Desktop/Behaviour/solomon/'
loopy_dir = '/Users/ruzenkakaldenbach/Desktop/Behaviour/Loopy_preprocessed_data/'
output_file = '/Users/ruzenkakaldenbach/Desktop/Behaviour/common_dataset.csv'

# Initialize an empty DataFrame for the combined dataset
common_dataset = pd.DataFrame()

# Loop through each dataset
for dataset in dataset_names:
    print(f"Processing {dataset}...")

    # Load Solomon data
    solomon_file = f'{solomon_dir}solomon_{dataset}_dichotomous.csv'
    solomon_data = pd.read_csv(solomon_file)

    # Load Loopy data
    loopy_file = f'{loopy_dir}Loopy_{dataset}__processed.csv'
    loopy_data = pd.read_csv(loopy_file)

    # Extract relevant dyad columns from Loopy data
    loopy_data_expanded = pd.DataFrame()
    for dyad, columns in [
        ('red-yellow', ['dist_c_ry', 'dist_f_ry', 'deg_ry', 'facing_ry']),
        ('blue-yellow', ['dist_c_by', 'dist_f_by', 'deg_by', 'facing_by']),
        ('red-blue', ['dist_c_rb', 'dist_f_rb', 'deg_rb', 'facing_rb']),
    ]:
        dyad_data = loopy_data[columns].copy()  # Extract and copy relevant columns
        dyad_data['dyad'] = dyad
        dyad_data['frame_timestamp'] = loopy_data['frame_timestamp']
        dyad_data['video'] = dataset  # Add a column with the dataset name
        dyad_data.columns = ['distance_central', 'distance_front', 'angle', 'facing', 'dyad', 'frame_timestamp', 'video']
        loopy_data_expanded = pd.concat([loopy_data_expanded, dyad_data], ignore_index=True)

    # Extract relevant dyad columns from Solomon data
    solomon_data_expanded = pd.DataFrame()
    for dyad, column in [
        ('red-yellow', 'si_ry'),
        ('blue-yellow', 'si_by'),
        ('red-blue', 'si_rb'),
    ]:
        dyad_data = solomon_data[['frame_timestamp', column]].copy()
        dyad_data['dyad'] = dyad
        dyad_data['video'] = dataset  # Add a column with the dataset name
        dyad_data.columns = ['frame_timestamp', 'interaction', 'dyad', 'video']
        solomon_data_expanded = pd.concat([solomon_data_expanded, dyad_data], ignore_index=True)

    # Merge Loopy and Solomon data
    merged_data = pd.merge(loopy_data_expanded, solomon_data_expanded, on=['frame_timestamp', 'dyad', 'video'], how='inner')

    # Append to the common dataset
    common_dataset = pd.concat([common_dataset, merged_data], ignore_index=True)

# Save the combined dataset to a CSV file
common_dataset.to_csv(output_file, index=False)
print(f"Saved combined dataset to {output_file}")

common_dataset
# Out:
# Processing DYAD06NF...
# Processing DYAD10NF...
# Processing DYAD11NF...
# Processing DYAD12NF...
# Processing DYAD14NF...
# Processing DYAD15NF...
# Processing DYAD16NF...
# Processing DYAD18NF...
# Processing DYAD21NF...
# Processing DYAD23NF...
# Processing DYAD24NF...
# Saved combined dataset to /Users/ruzenkakaldenbach/Desktop/Behaviour/common_dataset.csv
#        distance_central  distance_front       angle  facing        dyad  \
# 0            790.687264      800.025973    0.938036       0  red-yellow
# 1            792.303958      804.337355    1.308301       0  red-yellow
# 2            783.932649      793.611577    6.627138       0  red-yellow
# 3            853.480357      782.492790   22.068184       1  red-yellow
# 4            865.821415      780.327547   21.733946       1  red-yellow
# ...                 ...             ...         ...     ...         ...
# 79681       2164.464169     1912.349103  153.181946       1    red-blue
# 79682       2237.461605     2001.133668  153.815582       1    red-blue
# 79683       2160.783724     1892.775810  168.084441       1    red-blue
# 79684       2063.770212     1721.512237  167.615933       1    red-blue
# 79685       1754.960786     1436.226259  156.395828       1    red-blue
#
#        frame_timestamp     video  interaction
# 0                 0.00  DYAD06NF            0
# 1                 0.25  DYAD06NF            0
# 2                 0.50  DYAD06NF            0
# 3                 0.75  DYAD06NF            0
# 4                 1.00  DYAD06NF            0
# ...                ...       ...          ...
# 79681           602.75  DYAD24NF            0
# 79682           603.00  DYAD24NF            0
# 79683           603.25  DYAD24NF            0
# 79684           603.50  DYAD24NF            0
# 79685           603.75  DYAD24NF            0
#
# [79686 rows x 8 columns]

# %%
# Create the new column `distance` as the mean of `distance_front` and `distance_central`
common_dataset['distance'] = common_dataset[['distance_front', 'distance_central']].mean(axis=1)

# Drop the old columns `distance_front` and `distance_central`
common_dataset = common_dataset.drop(columns=['distance_front', 'distance_central'])

# Reorder the columns to place `distance` at the position of the original columns
columns_order = ['distance'] + [col for col in common_dataset.columns if col != 'distance']
common_dataset = common_dataset[columns_order]

# Save the updated dataset if needed
common_dataset.to_csv("/Users/ruzenkakaldenbach/Desktop/common_dataset.csv", index=False)

common_dataset
# Out:
#           distance       angle  facing        dyad  frame_timestamp     video  \
# 0       795.356618    0.938036       0  red-yellow             0.00  DYAD06NF
# 1       798.320657    1.308301       0  red-yellow             0.25  DYAD06NF
# 2       788.772113    6.627138       0  red-yellow             0.50  DYAD06NF
# 3       817.986573   22.068184       1  red-yellow             0.75  DYAD06NF
# 4       823.074481   21.733946       1  red-yellow             1.00  DYAD06NF
# ...            ...         ...     ...         ...              ...       ...
# 79681  2038.406636  153.181946       1    red-blue           602.75  DYAD24NF
# 79682  2119.297637  153.815582       1    red-blue           603.00  DYAD24NF
# 79683  2026.779767  168.084441       1    red-blue           603.25  DYAD24NF
# 79684  1892.641224  167.615933       1    red-blue           603.50  DYAD24NF
# 79685  1595.593522  156.395828       1    red-blue           603.75  DYAD24NF
#
#        interaction
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 79681            0
# 79682            0
# 79683            0
# 79684            0
# 79685            0
#
# [79686 rows x 7 columns]

# %% [markdown]
# # Apply ML

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import itertools

# Load the dataset
file_path = '/Users/ruzenkakaldenbach/Desktop/common_dataset.csv'
common_dataset = pd.read_csv(file_path)

# List of dataset names (videos)
dataset_names = ['DYAD06NF', 'DYAD10NF', 'DYAD11NF', 'DYAD12NF', 'DYAD14NF',
                  'DYAD15NF', 'DYAD16NF', 'DYAD18NF', 'DYAD21NF', 'DYAD23NF', 'DYAD24NF'
                ]

# Lists to store accuracies for averaging later
training_accuracies = []
testing_accuracies = []

# Divide into training and test datasets
# Generate all combinations of 3 test videos (leave 8 for training)
test_combinations = list(itertools.combinations(dataset_names, 3))

# Check for number of videos in dataset 
print("\nOriginal Video Distribution:")
print(common_dataset['video'].value_counts())

# Loop through each test set combination
for test_videos in test_combinations:  
    train_videos = [video for video in dataset_names if video not in test_videos] # All except selected 3 test videos
    
    print(f"Processing with test video: {test_videos}...")
    
    train_data = common_dataset[common_dataset['video'].isin(train_videos)]
    test_data = common_dataset[common_dataset['video'].isin(test_videos)]
   
    # Shuffle datasets after train-test split to prevent biases
    train_data_balanced = train_data.sample(frac=1, random_state=42).reset_index(drop=True)
    test_data_balanced = test_data.sample(frac=1, random_state=42).reset_index(drop=True)

    # Logistic Regression
    # Select predictors (distance, angle, facing) and outcome (interaction)
    predictors = ['distance', 'angle', 'facing']
    outcome = 'interaction'

    X_train = train_data_balanced[predictors]
    y_train = train_data_balanced[outcome]
    X_test = test_data_balanced[predictors]
    y_test = test_data_balanced[outcome]

    # Train the logistic regression model
    model = LogisticRegression(max_iter=1000, random_state=42)
    model.fit(X_train, y_train)

    # Evaluate on the training set
    y_train_pred = model.predict(X_train) # Once the model is fit, this only writes out the existing rows for how well the model fits the data to predict outcome from predictor
    train_accuracy = accuracy_score(y_train, y_train_pred) * 100 # Built-in function imported, compares the true values (y_train) with the predicted values (y_train_pred) and calculates the proportion of correct predictions
    training_accuracies.append(train_accuracy) # Store for averaging across videos later
    print("\nTraining Set Performance:")
    # Format and display the training confusion matrix
    cm_train = confusion_matrix(y_train, y_train_pred)
    cm_train_df = pd.DataFrame(
        cm_train,
        index=["Actual 0", "Actual 1"],
        columns=["Predicted 0", "Predicted 1"]
    )
    # True Positives (TP): Correctly predicted 1.
    # True Negatives (TN): Correctly predicted 0.
    # False Positives (FP): Predicted 1 when the true value was 0.
    # False Negatives (FN): Predicted 0 when the true value was 1.
    print("\nConfusion Matrix (Training):")
    print(cm_train_df)
    #print(confusion_matrix(y_train, y_train_pred))
    print("\nClassification Report (Training):")
    # Precision: Proportion of positive predictions (1) that were correct, TP/(TP+FP)
    # Recall or sensitivity: Proportion of actual positives (1) that were identified, TP/(TP+FN)
    # F1-Score: Harmonic mean of precision and recall, 2x(precision*recall)/(precision-recall)
    # Support: Total number of actual occurences within the 0 and 1 category
    print(classification_report(y_train, y_train_pred))
    print(f"\nAccuracy Score (Training): {train_accuracy:.2f}%")

    # Evaluate on the test set
    y_test_pred = model.predict(X_test)
    test_accuracy = accuracy_score(y_test, y_test_pred) * 100
    testing_accuracies.append(test_accuracy)
    print("\nTest Set Performance:")
    # Format and display the training confusion matrix
    cm_test = confusion_matrix(y_test, y_test_pred)
    cm_test_df = pd.DataFrame(
        cm_test,
        index=["Actual 0", "Actual 1"],
        columns=["Predicted 0", "Predicted 1"]
    )
    print("\nConfusion Matrix (Test):")
    print(cm_test_df)
    #print(confusion_matrix(y_test, y_test_pred))
    print("\nClassification Report (Test):")
    print(classification_report(y_test, y_test_pred))
    print(f"\nAccuracy Score (Test): {test_accuracy:.2f}%")

    # Save the balanced datasets for this split
    train_output_path = f'/Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_{",".join(test_videos)}.csv'
    test_output_path = f'/Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_{",".join(test_videos)}.csv'
    train_data_balanced.to_csv(train_output_path, index=False)
    test_data_balanced.to_csv(test_output_path, index=False)

    print(f"Training dataset for test videos {test_videos} saved to {train_output_path}")
    print(f"Test dataset for test videos {test_videos} saved to {test_output_path}")

# Calculate average accuracies
average_train_accuracy = sum(training_accuracies) / len(training_accuracies)
average_test_accuracy = sum(testing_accuracies) / len(testing_accuracies)

print("\nOverall Performance:")
print(f"Average Training Accuracy: {average_train_accuracy:.2f}%")
print(f"Average Testing Accuracy: {average_test_accuracy:.2f}%")
print("Processing complete.")
# Out:
# Original Video Distribution:
# video
# DYAD12NF    7368
# DYAD18NF    7320
# DYAD23NF    7260
# DYAD24NF    7248
# DYAD11NF    7239
# DYAD06NF    7236
# DYAD10NF    7203
# DYAD14NF    7203
# DYAD15NF    7203
# DYAD16NF    7203
# DYAD21NF    7203
# Name: count, dtype: int64
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD11NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48307         2025
# Actual 1         4767         2909
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93     50332
#            1       0.59      0.38      0.46      7676
#
#     accuracy                           0.88     58008
#    macro avg       0.75      0.67      0.70     58008
# weighted avg       0.87      0.88      0.87     58008
#
#
# Accuracy Score (Training): 88.29%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19886          367
# Actual 1          948          477
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97     20253
#            1       0.57      0.33      0.42      1425
#
#     accuracy                           0.94     21678
#    macro avg       0.76      0.66      0.69     21678
# weighted avg       0.93      0.94      0.93     21678
#
#
# Accuracy Score (Test): 93.93%
# Training dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD11NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD11NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD11NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD11NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD12NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49343         1534
# Actual 1         5022         1980
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     50877
#            1       0.56      0.28      0.38      7002
#
#     accuracy                           0.89     57879
#    macro avg       0.74      0.63      0.66     57879
# weighted avg       0.87      0.89      0.87     57879
#
#
# Accuracy Score (Training): 88.67%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19500          208
# Actual 1         1443          656
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     19708
#            1       0.76      0.31      0.44      2099
#
#     accuracy                           0.92     21807
#    macro avg       0.85      0.65      0.70     21807
# weighted avg       0.91      0.92      0.91     21807
#
#
# Accuracy Score (Test): 92.43%
# Training dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD12NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD12NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD12NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD12NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD14NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        47712         2195
# Actual 1         4570         3567
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93     49907
#            1       0.62      0.44      0.51      8137
#
#     accuracy                           0.88     58044
#    macro avg       0.77      0.70      0.72     58044
# weighted avg       0.87      0.88      0.87     58044
#
#
# Accuracy Score (Training): 88.35%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19845          833
# Actual 1          601          363
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97     20678
#            1       0.30      0.38      0.34       964
#
#     accuracy                           0.93     21642
#    macro avg       0.64      0.67      0.65     21642
# weighted avg       0.94      0.93      0.94     21642
#
#
# Accuracy Score (Test): 93.37%
# Training dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD14NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD14NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD14NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD14NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD15NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48475         2138
# Actual 1         4260         3171
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     50613
#            1       0.60      0.43      0.50      7431
#
#     accuracy                           0.89     58044
#    macro avg       0.76      0.69      0.72     58044
# weighted avg       0.88      0.89      0.88     58044
#
#
# Accuracy Score (Training): 88.98%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19466          506
# Actual 1         1345          325
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95     19972
#            1       0.39      0.19      0.26      1670
#
#     accuracy                           0.91     21642
#    macro avg       0.66      0.58      0.61     21642
# weighted avg       0.89      0.91      0.90     21642
#
#
# Accuracy Score (Test): 91.45%
# Training dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD15NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD15NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD15NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD15NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD16NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51080         1183
# Actual 1         4106         1675
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     52263
#            1       0.59      0.29      0.39      5781
#
#     accuracy                           0.91     58044
#    macro avg       0.76      0.63      0.67     58044
# weighted avg       0.89      0.91      0.89     58044
#
#
# Accuracy Score (Training): 90.89%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17894          428
# Actual 1         2492          828
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.92     18322
#            1       0.66      0.25      0.36      3320
#
#     accuracy                           0.87     21642
#    macro avg       0.77      0.61      0.64     21642
# weighted avg       0.84      0.87      0.84     21642
#
#
# Accuracy Score (Test): 86.51%
# Training dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD16NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD16NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD16NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD16NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD18NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48319         1935
# Actual 1         4736         2937
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94     50254
#            1       0.60      0.38      0.47      7673
#
#     accuracy                           0.88     57927
#    macro avg       0.76      0.67      0.70     57927
# weighted avg       0.87      0.88      0.87     57927
#
#
# Accuracy Score (Training): 88.48%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19682          649
# Actual 1          828          600
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     20331
#            1       0.48      0.42      0.45      1428
#
#     accuracy                           0.93     21759
#    macro avg       0.72      0.69      0.71     21759
# weighted avg       0.93      0.93      0.93     21759
#
#
# Accuracy Score (Test): 93.21%
# Training dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD18NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD18NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD18NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD18NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD21NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        47780         2110
# Actual 1         4989         3165
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93     49890
#            1       0.60      0.39      0.47      8154
#
#     accuracy                           0.88     58044
#    macro avg       0.75      0.67      0.70     58044
# weighted avg       0.86      0.88      0.87     58044
#
#
# Accuracy Score (Training): 87.77%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        20424          271
# Actual 1          758          189
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98     20695
#            1       0.41      0.20      0.27       947
#
#     accuracy                           0.95     21642
#    macro avg       0.69      0.59      0.62     21642
# weighted avg       0.94      0.95      0.94     21642
#
#
# Accuracy Score (Test): 95.25%
# Training dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD21NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD21NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD21NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD21NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD23NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48313         1897
# Actual 1         4966         2811
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93     50210
#            1       0.60      0.36      0.45      7777
#
#     accuracy                           0.88     57987
#    macro avg       0.75      0.66      0.69     57987
# weighted avg       0.87      0.88      0.87     57987
#
#
# Accuracy Score (Training): 88.16%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        20171          204
# Actual 1         1029          295
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     20375
#            1       0.59      0.22      0.32      1324
#
#     accuracy                           0.94     21699
#    macro avg       0.77      0.61      0.65     21699
# weighted avg       0.93      0.94      0.93     21699
#
#
# Accuracy Score (Test): 94.32%
# Training dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD23NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD23NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD23NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD23NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        47942         2120
# Actual 1         4837         3100
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93     50062
#            1       0.59      0.39      0.47      7937
#
#     accuracy                           0.88     57999
#    macro avg       0.75      0.67      0.70     57999
# weighted avg       0.87      0.88      0.87     57999
#
#
# Accuracy Score (Training): 88.00%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        20225          298
# Actual 1          913          251
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     20523
#            1       0.46      0.22      0.29      1164
#
#     accuracy                           0.94     21687
#    macro avg       0.71      0.60      0.63     21687
# weighted avg       0.93      0.94      0.93     21687
#
#
# Accuracy Score (Test): 94.42%
# Training dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD24NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD10NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD24NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD11NF', 'DYAD12NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49961         1376
# Actual 1         4832         1674
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     51337
#            1       0.55      0.26      0.35      6506
#
#     accuracy                           0.89     57843
#    macro avg       0.73      0.62      0.65     57843
# weighted avg       0.87      0.89      0.88     57843
#
#
# Accuracy Score (Training): 89.27%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19016          232
# Actual 1         1728          867
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95     19248
#            1       0.79      0.33      0.47      2595
#
#     accuracy                           0.91     21843
#    macro avg       0.85      0.66      0.71     21843
# weighted avg       0.90      0.91      0.89     21843
#
#
# Accuracy Score (Test): 91.03%
# Training dataset for test videos ('DYAD06NF', 'DYAD11NF', 'DYAD12NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD11NF,DYAD12NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD11NF', 'DYAD12NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD11NF,DYAD12NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD11NF', 'DYAD14NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48307         2060
# Actual 1         4415         3226
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     50367
#            1       0.61      0.42      0.50      7641
#
#     accuracy                           0.89     58008
#    macro avg       0.76      0.69      0.72     58008
# weighted avg       0.88      0.89      0.88     58008
#
#
# Accuracy Score (Training): 88.84%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19387          831
# Actual 1          846          614
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     20218
#            1       0.42      0.42      0.42      1460
#
#     accuracy                           0.92     21678
#    macro avg       0.69      0.69      0.69     21678
# weighted avg       0.92      0.92      0.92     21678
#
#
# Accuracy Score (Test): 92.26%
# Training dataset for test videos ('DYAD06NF', 'DYAD11NF', 'DYAD14NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD11NF,DYAD14NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD11NF', 'DYAD14NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD11NF,DYAD14NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD11NF', 'DYAD15NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49089         1984
# Actual 1         4095         2840
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     51073
#            1       0.59      0.41      0.48      6935
#
#     accuracy                           0.90     58008
#    macro avg       0.76      0.69      0.71     58008
# weighted avg       0.88      0.90      0.89     58008
#
#
# Accuracy Score (Training): 89.52%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19007          505
# Actual 1         1592          574
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95     19512
#            1       0.53      0.27      0.35      2166
#
#     accuracy                           0.90     21678
#    macro avg       0.73      0.62      0.65     21678
# weighted avg       0.88      0.90      0.89     21678
#
#
# Accuracy Score (Test): 90.33%
# Training dataset for test videos ('DYAD06NF', 'DYAD11NF', 'DYAD15NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD11NF,DYAD15NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD11NF', 'DYAD15NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD11NF,DYAD15NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD11NF', 'DYAD16NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51707         1016
# Actual 1         3904         1381
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     52723
#            1       0.58      0.26      0.36      5285
#
#     accuracy                           0.92     58008
#    macro avg       0.75      0.62      0.66     58008
# weighted avg       0.90      0.92      0.90     58008
#
#
# Accuracy Score (Training): 91.52%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17432          430
# Actual 1         2839          977
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.91     17862
#            1       0.69      0.26      0.37      3816
#
#     accuracy                           0.85     21678
#    macro avg       0.78      0.62      0.64     21678
# weighted avg       0.83      0.85      0.82     21678
#
#
# Accuracy Score (Test): 84.92%
# Training dataset for test videos ('DYAD06NF', 'DYAD11NF', 'DYAD16NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD11NF,DYAD16NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD11NF', 'DYAD16NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD11NF,DYAD16NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD11NF', 'DYAD18NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48937         1777
# Actual 1         4574         2603
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94     50714
#            1       0.59      0.36      0.45      7177
#
#     accuracy                           0.89     57891
#    macro avg       0.75      0.66      0.69     57891
# weighted avg       0.87      0.89      0.88     57891
#
#
# Accuracy Score (Training): 89.03%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19192          679
# Actual 1         1072          852
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96     19871
#            1       0.56      0.44      0.49      1924
#
#     accuracy                           0.92     21795
#    macro avg       0.75      0.70      0.72     21795
# weighted avg       0.91      0.92      0.92     21795
#
#
# Accuracy Score (Test): 91.97%
# Training dataset for test videos ('DYAD06NF', 'DYAD11NF', 'DYAD18NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD11NF,DYAD18NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD11NF', 'DYAD18NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD11NF,DYAD18NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD11NF', 'DYAD21NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48406         1944
# Actual 1         4828         2830
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93     50350
#            1       0.59      0.37      0.46      7658
#
#     accuracy                           0.88     58008
#    macro avg       0.75      0.67      0.69     58008
# weighted avg       0.87      0.88      0.87     58008
#
#
# Accuracy Score (Training): 88.33%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19939          296
# Actual 1         1011          432
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     20235
#            1       0.59      0.30      0.40      1443
#
#     accuracy                           0.94     21678
#    macro avg       0.77      0.64      0.68     21678
# weighted avg       0.93      0.94      0.93     21678
#
#
# Accuracy Score (Test): 93.97%
# Training dataset for test videos ('DYAD06NF', 'DYAD11NF', 'DYAD21NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD11NF,DYAD21NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD11NF', 'DYAD21NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD11NF,DYAD21NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD11NF', 'DYAD23NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48934         1736
# Actual 1         4754         2527
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     50670
#            1       0.59      0.35      0.44      7281
#
#     accuracy                           0.89     57951
#    macro avg       0.75      0.66      0.69     57951
# weighted avg       0.87      0.89      0.87     57951
#
#
# Accuracy Score (Training): 88.80%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19690          225
# Actual 1         1326          494
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96     19915
#            1       0.69      0.27      0.39      1820
#
#     accuracy                           0.93     21735
#    macro avg       0.81      0.63      0.68     21735
# weighted avg       0.92      0.93      0.91     21735
#
#
# Accuracy Score (Test): 92.86%
# Training dataset for test videos ('DYAD06NF', 'DYAD11NF', 'DYAD23NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD11NF,DYAD23NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD11NF', 'DYAD23NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD11NF,DYAD23NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD11NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48569         1953
# Actual 1         4659         2782
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94     50522
#            1       0.59      0.37      0.46      7441
#
#     accuracy                           0.89     57963
#    macro avg       0.75      0.67      0.70     57963
# weighted avg       0.87      0.89      0.87     57963
#
#
# Accuracy Score (Training): 88.59%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19734          329
# Actual 1         1164          496
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96     20063
#            1       0.60      0.30      0.40      1660
#
#     accuracy                           0.93     21723
#    macro avg       0.77      0.64      0.68     21723
# weighted avg       0.92      0.93      0.92     21723
#
#
# Accuracy Score (Test): 93.13%
# Training dataset for test videos ('DYAD06NF', 'DYAD11NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD11NF,DYAD24NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD11NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD11NF,DYAD24NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD12NF', 'DYAD14NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49321         1591
# Actual 1         4710         2257
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     50912
#            1       0.59      0.32      0.42      6967
#
#     accuracy                           0.89     57879
#    macro avg       0.75      0.65      0.68     57879
# weighted avg       0.87      0.89      0.88     57879
#
#
# Accuracy Score (Training): 89.11%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19109          564
# Actual 1         1287          847
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95     19673
#            1       0.60      0.40      0.48      2134
#
#     accuracy                           0.92     21807
#    macro avg       0.77      0.68      0.72     21807
# weighted avg       0.90      0.92      0.91     21807
#
#
# Accuracy Score (Test): 91.51%
# Training dataset for test videos ('DYAD06NF', 'DYAD12NF', 'DYAD14NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD12NF,DYAD14NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD12NF', 'DYAD14NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD12NF,DYAD14NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD12NF', 'DYAD15NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        50059         1559
# Actual 1         4274         1987
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94     51618
#            1       0.56      0.32      0.41      6261
#
#     accuracy                           0.90     57879
#    macro avg       0.74      0.64      0.68     57879
# weighted avg       0.88      0.90      0.89     57879
#
#
# Accuracy Score (Training): 89.92%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        18637          330
# Actual 1         2121          719
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94     18967
#            1       0.69      0.25      0.37      2840
#
#     accuracy                           0.89     21807
#    macro avg       0.79      0.62      0.65     21807
# weighted avg       0.87      0.89      0.86     21807
#
#
# Accuracy Score (Test): 88.76%
# Training dataset for test videos ('DYAD06NF', 'DYAD12NF', 'DYAD15NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD12NF,DYAD15NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD12NF', 'DYAD15NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD12NF,DYAD15NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD12NF', 'DYAD16NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        52688          580
# Actual 1         3902          709
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     53268
#            1       0.55      0.15      0.24      4611
#
#     accuracy                           0.92     57879
#    macro avg       0.74      0.57      0.60     57879
# weighted avg       0.90      0.92      0.90     57879
#
#
# Accuracy Score (Training): 92.26%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17104          213
# Actual 1         3877          613
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.82      0.99      0.89     17317
#            1       0.74      0.14      0.23      4490
#
#     accuracy                           0.81     21807
#    macro avg       0.78      0.56      0.56     21807
# weighted avg       0.80      0.81      0.76     21807
#
#
# Accuracy Score (Test): 81.24%
# Training dataset for test videos ('DYAD06NF', 'DYAD12NF', 'DYAD16NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD12NF,DYAD16NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD12NF', 'DYAD16NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD12NF,DYAD16NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD12NF', 'DYAD18NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49925         1334
# Actual 1         4768         1735
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     51259
#            1       0.57      0.27      0.36      6503
#
#     accuracy                           0.89     57762
#    macro avg       0.74      0.62      0.65     57762
# weighted avg       0.87      0.89      0.88     57762
#
#
# Accuracy Score (Training): 89.44%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        18933          393
# Actual 1         1710          888
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95     19326
#            1       0.69      0.34      0.46      2598
#
#     accuracy                           0.90     21924
#    macro avg       0.81      0.66      0.70     21924
# weighted avg       0.89      0.90      0.89     21924
#
#
# Accuracy Score (Test): 90.41%
# Training dataset for test videos ('DYAD06NF', 'DYAD12NF', 'DYAD18NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD12NF,DYAD18NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD12NF', 'DYAD18NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD12NF,DYAD18NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD12NF', 'DYAD21NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49417         1478
# Actual 1         5056         1928
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     50895
#            1       0.57      0.28      0.37      6984
#
#     accuracy                           0.89     57879
#    macro avg       0.74      0.62      0.65     57879
# weighted avg       0.87      0.89      0.87     57879
#
#
# Accuracy Score (Training): 88.71%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19542          148
# Actual 1         1523          594
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     19690
#            1       0.80      0.28      0.42      2117
#
#     accuracy                           0.92     21807
#    macro avg       0.86      0.64      0.69     21807
# weighted avg       0.92      0.92      0.91     21807
#
#
# Accuracy Score (Test): 92.34%
# Training dataset for test videos ('DYAD06NF', 'DYAD12NF', 'DYAD21NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD12NF,DYAD21NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD12NF', 'DYAD21NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD12NF,DYAD21NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD12NF', 'DYAD23NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49928         1287
# Actual 1         4945         1662
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     51215
#            1       0.56      0.25      0.35      6607
#
#     accuracy                           0.89     57822
#    macro avg       0.74      0.61      0.64     57822
# weighted avg       0.87      0.89      0.87     57822
#
#
# Accuracy Score (Training): 89.22%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19272           98
# Actual 1         1896          598
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95     19370
#            1       0.86      0.24      0.37      2494
#
#     accuracy                           0.91     21864
#    macro avg       0.88      0.62      0.66     21864
# weighted avg       0.90      0.91      0.89     21864
#
#
# Accuracy Score (Test): 90.88%
# Training dataset for test videos ('DYAD06NF', 'DYAD12NF', 'DYAD23NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD12NF,DYAD23NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD12NF', 'DYAD23NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD12NF,DYAD23NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD12NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49595         1472
# Actual 1         4890         1877
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     51067
#            1       0.56      0.28      0.37      6767
#
#     accuracy                           0.89     57834
#    macro avg       0.74      0.62      0.66     57834
# weighted avg       0.87      0.89      0.87     57834
#
#
# Accuracy Score (Training): 89.00%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19346          172
# Actual 1         1701          633
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95     19518
#            1       0.79      0.27      0.40      2334
#
#     accuracy                           0.91     21852
#    macro avg       0.85      0.63      0.68     21852
# weighted avg       0.90      0.91      0.90     21852
#
#
# Accuracy Score (Test): 91.43%
# Training dataset for test videos ('DYAD06NF', 'DYAD12NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD12NF,DYAD24NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD12NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD12NF,DYAD24NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD14NF', 'DYAD15NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48506         2142
# Actual 1         3835         3561
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94     50648
#            1       0.62      0.48      0.54      7396
#
#     accuracy                           0.90     58044
#    macro avg       0.78      0.72      0.74     58044
# weighted avg       0.89      0.90      0.89     58044
#
#
# Accuracy Score (Training): 89.70%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        18928         1009
# Actual 1         1246          459
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94     19937
#            1       0.31      0.27      0.29      1705
#
#     accuracy                           0.90     21642
#    macro avg       0.63      0.61      0.62     21642
# weighted avg       0.89      0.90      0.89     21642
#
#
# Accuracy Score (Test): 89.58%
# Training dataset for test videos ('DYAD06NF', 'DYAD14NF', 'DYAD15NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD14NF,DYAD15NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD14NF', 'DYAD15NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD14NF,DYAD15NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD14NF', 'DYAD16NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51092         1206
# Actual 1         3815         1931
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     52298
#            1       0.62      0.34      0.43      5746
#
#     accuracy                           0.91     58044
#    macro avg       0.77      0.66      0.69     58044
# weighted avg       0.90      0.91      0.90     58044
#
#
# Accuracy Score (Training): 91.35%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17440          847
# Actual 1         2251         1104
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92     18287
#            1       0.57      0.33      0.42      3355
#
#     accuracy                           0.86     21642
#    macro avg       0.73      0.64      0.67     21642
# weighted avg       0.84      0.86      0.84     21642
#
#
# Accuracy Score (Test): 85.69%
# Training dataset for test videos ('DYAD06NF', 'DYAD14NF', 'DYAD16NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD14NF,DYAD16NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD14NF', 'DYAD16NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD14NF,DYAD16NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD14NF', 'DYAD18NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48338         1951
# Actual 1         4368         3270
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     50289
#            1       0.63      0.43      0.51      7638
#
#     accuracy                           0.89     57927
#    macro avg       0.77      0.69      0.72     57927
# weighted avg       0.88      0.89      0.88     57927
#
#
# Accuracy Score (Training): 89.09%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19089         1207
# Actual 1          665          798
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95     20296
#            1       0.40      0.55      0.46      1463
#
#     accuracy                           0.91     21759
#    macro avg       0.68      0.74      0.71     21759
# weighted avg       0.93      0.91      0.92     21759
#
#
# Accuracy Score (Test): 91.40%
# Training dataset for test videos ('DYAD06NF', 'DYAD14NF', 'DYAD18NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD14NF,DYAD18NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD14NF', 'DYAD18NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD14NF,DYAD18NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD14NF', 'DYAD21NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        47787         2138
# Actual 1         4652         3467
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93     49925
#            1       0.62      0.43      0.51      8119
#
#     accuracy                           0.88     58044
#    macro avg       0.76      0.69      0.72     58044
# weighted avg       0.87      0.88      0.87     58044
#
#
# Accuracy Score (Training): 88.30%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19948          712
# Actual 1          655          327
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97     20660
#            1       0.31      0.33      0.32       982
#
#     accuracy                           0.94     21642
#    macro avg       0.64      0.65      0.65     21642
# weighted avg       0.94      0.94      0.94     21642
#
#
# Accuracy Score (Test): 93.68%
# Training dataset for test videos ('DYAD06NF', 'DYAD14NF', 'DYAD21NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD14NF,DYAD21NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD14NF', 'DYAD21NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD14NF,DYAD21NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD14NF', 'DYAD23NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48312         1933
# Actual 1         4669         3073
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94     50245
#            1       0.61      0.40      0.48      7742
#
#     accuracy                           0.89     57987
#    macro avg       0.76      0.68      0.71     57987
# weighted avg       0.87      0.89      0.88     57987
#
#
# Accuracy Score (Training): 88.61%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19737          603
# Actual 1          920          439
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     20340
#            1       0.42      0.32      0.37      1359
#
#     accuracy                           0.93     21699
#    macro avg       0.69      0.65      0.66     21699
# weighted avg       0.92      0.93      0.93     21699
#
#
# Accuracy Score (Test): 92.98%
# Training dataset for test videos ('DYAD06NF', 'DYAD14NF', 'DYAD23NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD14NF,DYAD23NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD14NF', 'DYAD23NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD14NF,DYAD23NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD14NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        47944         2153
# Actual 1         4459         3443
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94     50097
#            1       0.62      0.44      0.51      7902
#
#     accuracy                           0.89     57999
#    macro avg       0.77      0.70      0.72     57999
# weighted avg       0.87      0.89      0.88     57999
#
#
# Accuracy Score (Training): 88.60%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19732          756
# Actual 1          811          388
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     20488
#            1       0.34      0.32      0.33      1199
#
#     accuracy                           0.93     21687
#    macro avg       0.65      0.64      0.65     21687
# weighted avg       0.93      0.93      0.93     21687
#
#
# Accuracy Score (Test): 92.77%
# Training dataset for test videos ('DYAD06NF', 'DYAD14NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD14NF,DYAD24NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD14NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD14NF,DYAD24NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD15NF', 'DYAD16NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51814         1190
# Actual 1         3405         1635
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96     53004
#            1       0.58      0.32      0.42      5040
#
#     accuracy                           0.92     58044
#    macro avg       0.76      0.65      0.69     58044
# weighted avg       0.91      0.92      0.91     58044
#
#
# Accuracy Score (Training): 92.08%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17032          549
# Actual 1         3143          918
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.84      0.97      0.90     17581
#            1       0.63      0.23      0.33      4061
#
#     accuracy                           0.83     21642
#    macro avg       0.73      0.60      0.62     21642
# weighted avg       0.80      0.83      0.80     21642
#
#
# Accuracy Score (Test): 82.94%
# Training dataset for test videos ('DYAD06NF', 'DYAD15NF', 'DYAD16NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD15NF,DYAD16NF.csv
# Test dataset for test videos ('DYAD06NF', 'DYAD15NF', 'DYAD16NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD15NF,DYAD16NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD15NF', 'DYAD18NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49077         1918
# Actual 1         4023         2909
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     50995
#            1       0.60      0.42      0.49      6932
#
#     accuracy                           0.90     57927
#    macro avg       0.76      0.69      0.72     57927
# weighted avg       0.89      0.90      0.89     57927
#
#
# Accuracy Score (Training): 89.74%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        18807          783
# Actual 1         1488          681
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94     19590
#            1       0.47      0.31      0.37      2169
#
#     accuracy                           0.90     21759
#    macro avg       0.70      0.64      0.66     21759
# weighted avg       0.88      0.90      0.89     21759
#
#
# Accuracy Score (Test): 89.56%
# Training dataset for test videos ('DYAD06NF', 'DYAD15NF', 'DYAD18NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD15NF,DYAD18NF.csv
# ...
#
#
# Accuracy Score (Training): 89.62%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19112          406
# Actual 1         1720          473
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95     19518
#            1       0.54      0.22      0.31      2193
#
#     accuracy                           0.90     21711
#    macro avg       0.73      0.60      0.63     21711
# weighted avg       0.88      0.90      0.88     21711
#
#
# Accuracy Score (Test): 90.21%
# Training dataset for test videos ('DYAD15NF', 'DYAD23NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD15NF,DYAD23NF,DYAD24NF.csv
# Test dataset for test videos ('DYAD15NF', 'DYAD23NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD15NF,DYAD23NF,DYAD24NF.csv
# Processing with test video: ('DYAD16NF', 'DYAD18NF', 'DYAD21NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51677          912
# Actual 1         3934         1437
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96     52589
#            1       0.61      0.27      0.37      5371
#
#     accuracy                           0.92     57960
#    macro avg       0.77      0.63      0.66     57960
# weighted avg       0.90      0.92      0.90     57960
#
#
# Accuracy Score (Training): 91.64%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17349          647
# Actual 1         2635         1095
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91     17996
#            1       0.63      0.29      0.40      3730
#
#     accuracy                           0.85     21726
#    macro avg       0.75      0.63      0.66     21726
# weighted avg       0.83      0.85      0.83     21726
#
#
# Accuracy Score (Test): 84.89%
# Training dataset for test videos ('DYAD16NF', 'DYAD18NF', 'DYAD21NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD16NF,DYAD18NF,DYAD21NF.csv
# Test dataset for test videos ('DYAD16NF', 'DYAD18NF', 'DYAD21NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD16NF,DYAD18NF,DYAD21NF.csv
# Processing with test video: ('DYAD16NF', 'DYAD18NF', 'DYAD23NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        52156          753
# Actual 1         3829         1165
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     52909
#            1       0.61      0.23      0.34      4994
#
#     accuracy                           0.92     57903
#    macro avg       0.77      0.61      0.65     57903
# weighted avg       0.90      0.92      0.90     57903
#
#
# Accuracy Score (Training): 92.09%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17183          493
# Actual 1         3103         1004
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91     17676
#            1       0.67      0.24      0.36      4107
#
#     accuracy                           0.83     21783
#    macro avg       0.76      0.61      0.63     21783
# weighted avg       0.81      0.83      0.80     21783
#
#
# Accuracy Score (Test): 83.49%
# Training dataset for test videos ('DYAD16NF', 'DYAD18NF', 'DYAD23NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD16NF,DYAD18NF,DYAD23NF.csv
# Test dataset for test videos ('DYAD16NF', 'DYAD18NF', 'DYAD23NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD16NF,DYAD18NF,DYAD23NF.csv
# Processing with test video: ('DYAD16NF', 'DYAD18NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51836          925
# Actual 1         3767         1387
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96     52761
#            1       0.60      0.27      0.37      5154
#
#     accuracy                           0.92     57915
#    macro avg       0.77      0.63      0.66     57915
# weighted avg       0.90      0.92      0.90     57915
#
#
# Accuracy Score (Training): 91.90%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17154          670
# Actual 1         2805         1142
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91     17824
#            1       0.63      0.29      0.40      3947
#
#     accuracy                           0.84     21771
#    macro avg       0.74      0.63      0.65     21771
# weighted avg       0.82      0.84      0.82     21771
#
#
# Accuracy Score (Test): 84.04%
# Training dataset for test videos ('DYAD16NF', 'DYAD18NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD16NF,DYAD18NF,DYAD24NF.csv
# Test dataset for test videos ('DYAD16NF', 'DYAD18NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD16NF,DYAD18NF,DYAD24NF.csv
# Processing with test video: ('DYAD16NF', 'DYAD21NF', 'DYAD23NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51657          888
# Actual 1         4103         1372
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     52545
#            1       0.61      0.25      0.35      5475
#
#     accuracy                           0.91     58020
#    macro avg       0.77      0.62      0.65     58020
# weighted avg       0.90      0.91      0.90     58020
#
#
# Accuracy Score (Training): 91.40%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17736          304
# Actual 1         2906          720
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92     18040
#            1       0.70      0.20      0.31      3626
#
#     accuracy                           0.85     21666
#    macro avg       0.78      0.59      0.61     21666
# weighted avg       0.83      0.85      0.82     21666
#
#
# Accuracy Score (Test): 85.18%
# Training dataset for test videos ('DYAD16NF', 'DYAD21NF', 'DYAD23NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD16NF,DYAD21NF,DYAD23NF.csv
# Test dataset for test videos ('DYAD16NF', 'DYAD21NF', 'DYAD23NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD16NF,DYAD21NF,DYAD23NF.csv
# Processing with test video: ('DYAD16NF', 'DYAD21NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51338         1059
# Actual 1         4056         1579
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     52397
#            1       0.60      0.28      0.38      5635
#
#     accuracy                           0.91     58032
#    macro avg       0.76      0.63      0.67     58032
# weighted avg       0.89      0.91      0.90     58032
#
#
# Accuracy Score (Training): 91.19%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17768          420
# Actual 1         2660          806
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92     18188
#            1       0.66      0.23      0.34      3466
#
#     accuracy                           0.86     21654
#    macro avg       0.76      0.60      0.63     21654
# weighted avg       0.84      0.86      0.83     21654
#
#
# Accuracy Score (Test): 85.78%
# Training dataset for test videos ('DYAD16NF', 'DYAD21NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD16NF,DYAD21NF,DYAD24NF.csv
# Test dataset for test videos ('DYAD16NF', 'DYAD21NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD16NF,DYAD21NF,DYAD24NF.csv
# Processing with test video: ('DYAD16NF', 'DYAD23NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51854          863
# Actual 1         3933         1325
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96     52717
#            1       0.61      0.25      0.36      5258
#
#     accuracy                           0.92     57975
#    macro avg       0.77      0.62      0.66     57975
# weighted avg       0.90      0.92      0.90     57975
#
#
# Accuracy Score (Training): 91.73%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17535          333
# Actual 1         3091          752
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91     17868
#            1       0.69      0.20      0.31      3843
#
#     accuracy                           0.84     21711
#    macro avg       0.77      0.59      0.61     21711
# weighted avg       0.82      0.84      0.80     21711
#
#
# Accuracy Score (Test): 84.23%
# Training dataset for test videos ('DYAD16NF', 'DYAD23NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD16NF,DYAD23NF,DYAD24NF.csv
# Test dataset for test videos ('DYAD16NF', 'DYAD23NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD16NF,DYAD23NF,DYAD24NF.csv
# Processing with test video: ('DYAD18NF', 'DYAD21NF', 'DYAD23NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48931         1605
# Actual 1         4830         2537
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     50536
#            1       0.61      0.34      0.44      7367
#
#     accuracy                           0.89     57903
#    macro avg       0.76      0.66      0.69     57903
# weighted avg       0.87      0.89      0.88     57903
#
#
# Accuracy Score (Training): 88.89%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19484          565
# Actual 1         1043          691
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96     20049
#            1       0.55      0.40      0.46      1734
#
#     accuracy                           0.93     21783
#    macro avg       0.75      0.69      0.71     21783
# weighted avg       0.92      0.93      0.92     21783
#
#
# Accuracy Score (Test): 92.62%
# Training dataset for test videos ('DYAD18NF', 'DYAD21NF', 'DYAD23NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD18NF,DYAD21NF,DYAD23NF.csv
# Test dataset for test videos ('DYAD18NF', 'DYAD21NF', 'DYAD23NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD18NF,DYAD21NF,DYAD23NF.csv
# Processing with test video: ('DYAD18NF', 'DYAD21NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48554         1834
# Actual 1         4685         2842
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94     50388
#            1       0.61      0.38      0.47      7527
#
#     accuracy                           0.89     57915
#    macro avg       0.76      0.67      0.70     57915
# weighted avg       0.87      0.89      0.88     57915
#
#
# Accuracy Score (Training): 88.74%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19482          715
# Actual 1          887          687
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     20197
#            1       0.49      0.44      0.46      1574
#
#     accuracy                           0.93     21771
#    macro avg       0.72      0.70      0.71     21771
# weighted avg       0.92      0.93      0.92     21771
#
#
# Accuracy Score (Test): 92.64%
# Training dataset for test videos ('DYAD18NF', 'DYAD21NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD18NF,DYAD21NF,DYAD24NF.csv
# Test dataset for test videos ('DYAD18NF', 'DYAD21NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD18NF,DYAD21NF,DYAD24NF.csv
# Processing with test video: ('DYAD18NF', 'DYAD23NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49094         1614
# Actual 1         4651         2499
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     50708
#            1       0.61      0.35      0.44      7150
#
#     accuracy                           0.89     57858
#    macro avg       0.76      0.66      0.69     57858
# weighted avg       0.88      0.89      0.88     57858
#
#
# Accuracy Score (Training): 89.17%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19267          610
# Actual 1         1192          759
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96     19877
#            1       0.55      0.39      0.46      1951
#
#     accuracy                           0.92     21828
#    macro avg       0.75      0.68      0.71     21828
# weighted avg       0.91      0.92      0.91     21828
#
#
# Accuracy Score (Test): 91.74%
# Training dataset for test videos ('DYAD18NF', 'DYAD23NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD18NF,DYAD23NF,DYAD24NF.csv
# Test dataset for test videos ('DYAD18NF', 'DYAD23NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD18NF,DYAD23NF,DYAD24NF.csv
# Processing with test video: ('DYAD21NF', 'DYAD23NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48561         1783
# Actual 1         4893         2738
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94     50344
#            1       0.61      0.36      0.45      7631
#
#     accuracy                           0.88     57975
#    macro avg       0.76      0.66      0.69     57975
# weighted avg       0.87      0.88      0.87     57975
#
#
# Accuracy Score (Training): 88.48%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19996          245
# Actual 1         1125          345
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     20241
#            1       0.58      0.23      0.33      1470
#
#     accuracy                           0.94     21711
#    macro avg       0.77      0.61      0.65     21711
# weighted avg       0.92      0.94      0.92     21711
#
#
# Accuracy Score (Test): 93.69%
# Training dataset for test videos ('DYAD21NF', 'DYAD23NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD21NF,DYAD23NF,DYAD24NF.csv
# Test dataset for test videos ('DYAD21NF', 'DYAD23NF', 'DYAD24NF') saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD21NF,DYAD23NF,DYAD24NF.csv
#
# Overall Performance:
# Average Training Accuracy: 89.90%
# Average Testing Accuracy: 89.28%
# Processing complete.

# %% [markdown]
# ### Include interaction between preditors

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import itertools

# Function to add interaction terms
def add_interaction_terms(data):
    data = data.copy()
    data['distance_angle'] = data['distance'] * data['angle']
    data['distance_facing'] = data['distance'] * data['facing']
    data['angle_facing'] = data['angle'] * data['facing']
    data['distance_angle_facing'] = data['distance'] * data['angle'] * data['facing']
    return data

# Load the dataset
file_path = '/Users/ruzenkakaldenbach/Desktop/common_dataset.csv'
common_dataset = pd.read_csv(file_path)

# List of dataset names (videos)
dataset_names = ['DYAD06NF', 'DYAD10NF', 'DYAD11NF', 'DYAD12NF', 'DYAD14NF',
                  'DYAD15NF', 'DYAD16NF', 'DYAD18NF', 'DYAD21NF', 'DYAD23NF', 'DYAD24NF'
                ]


# Lists to store accuracies for averaging later
training_accuracies = []
testing_accuracies = []


# Divide into training and test datasets
# Generate all combinations of 3 test videos (leave 8 for training)
test_combinations = list(itertools.combinations(dataset_names, 3))

# Check for number of videos in dataset 
print("\nOriginal Video Distribution:")
print(common_dataset['video'].value_counts())

for test_videos in test_combinations:  
    train_videos = [video for video in dataset_names if video not in test_videos] # All except selected 3 test videos

    print(f"Processing with test video: {test_videos}...")

    train_data = common_dataset[common_dataset['video'].isin(train_videos)]
    test_data = common_dataset[common_dataset['video'].isin(test_videos)]

    # Shuffle datasets after train-test split to prevent biases
    train_data_balanced = train_data.sample(frac=1, random_state=42).reset_index(drop=True)
    test_data_balanced = test_data.sample(frac=1, random_state=42).reset_index(drop=True)

    # Add interaction terms to both train and test sets
    train_data_balanced = add_interaction_terms(train_data_balanced)
    test_data_balanced = add_interaction_terms(test_data_balanced)

    # Logistic Regression
    # Update predictors list to include interaction terms
    predictors = ['distance', 'angle', 'facing', 'distance_angle', 'distance_facing', 'angle_facing', 'distance_angle_facing']
    outcome = 'interaction'

    X_train = train_data_balanced[predictors]
    y_train = train_data_balanced[outcome]
    X_test = test_data_balanced[predictors]
    y_test = test_data_balanced[outcome]

    # Train the logistic regression model
    model = LogisticRegression(max_iter=1000, random_state=42)
    model.fit(X_train, y_train)

    # Evaluate on the training set
    y_train_pred = model.predict(X_train) # Once the model is fit, this only writes out the existing rows for how well the model fits the data to predict outcome from predictor
    train_accuracy = accuracy_score(y_train, y_train_pred) * 100 # Built-in function imported, compares the true values (y_train) with the predicted values (y_train_pred) and calculates the proportion of correct predictions
    training_accuracies.append(train_accuracy) # Store for averaging across videos later
    
    print("\nTraining Set Performance:")
    # Format and display the training confusion matrix
    cm_train = confusion_matrix(y_train, y_train_pred)
    cm_train_df = pd.DataFrame(
        cm_train,
        index=["Actual 0", "Actual 1"],
        columns=["Predicted 0", "Predicted 1"]
    )
    # True Positives (TP): Correctly predicted 1.
    # True Negatives (TN): Correctly predicted 0.
    # False Positives (FP): Predicted 1 when the true value was 0.
    # False Negatives (FN): Predicted 0 when the true value was 1.
    print("\nConfusion Matrix (Training):")
    print(cm_train_df)
    #print(confusion_matrix(y_train, y_train_pred))
    print("\nClassification Report (Training):")
    # Precision: Proportion of positive predictions (1) that were correct, TP/(TP+FP)
    # Recall or sensitivity: Proportion of actual positives (1) that were identified, TP/(TP+FN)
    # F1-Score: Harmonic mean of precision and recall, 2x(precision*recall)/(precision-recall)
    # Support: Total number of actual occurences within the 0 and 1 category
    print(classification_report(y_train, y_train_pred))
    print(f"\nAccuracy Score (Training): {train_accuracy:.2f}%")

    # Evaluate on the test set
    y_test_pred = model.predict(X_test)
    test_accuracy = accuracy_score(y_test, y_test_pred) * 100
    testing_accuracies.append(test_accuracy)
    print("\nTest Set Performance:")
    # Format and display the training confusion matrix
    cm_test = confusion_matrix(y_test, y_test_pred)
    cm_test_df = pd.DataFrame(
        cm_test,
        index=["Actual 0", "Actual 1"],
        columns=["Predicted 0", "Predicted 1"]
    )
    print("\nConfusion Matrix (Test):")
    print(cm_test_df)
    #print(confusion_matrix(y_test, y_test_pred))
    print("\nClassification Report (Test):")
    print(classification_report(y_test, y_test_pred))
    print(f"\nAccuracy Score (Test): {test_accuracy:.2f}%")

    # Save the balanced datasets for this split
    train_output_path = f'/Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_{",".join(test_videos)}.csv'
    test_output_path = f'/Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_{",".join(test_videos)}.csv'
    train_data_balanced.to_csv(train_output_path, index=False)
    test_data_balanced.to_csv(test_output_path, index=False)

    print(f"Training dataset for test video {test_video} saved to {train_output_path}")
    print(f"Test dataset for test video {test_video} saved to {test_output_path}")

# Calculate average accuracies
average_train_accuracy = sum(training_accuracies) / len(training_accuracies)
average_test_accuracy = sum(testing_accuracies) / len(testing_accuracies)

print("\nOverall Performance:")
print(f"Average Training Accuracy: {average_train_accuracy:.2f}%")
print(f"Average Testing Accuracy: {average_test_accuracy:.2f}%")
print("Processing complete.")
# Out:
# Original Video Distribution:
# video
# DYAD12NF    7368
# DYAD18NF    7320
# DYAD23NF    7260
# DYAD24NF    7248
# DYAD11NF    7239
# DYAD06NF    7236
# DYAD10NF    7203
# DYAD14NF    7203
# DYAD15NF    7203
# DYAD16NF    7203
# DYAD21NF    7203
# Name: count, dtype: int64
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD11NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48351         1981
# Actual 1         4745         2931
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93     50332
#            1       0.60      0.38      0.47      7676
#
#     accuracy                           0.88     58008
#    macro avg       0.75      0.67      0.70     58008
# weighted avg       0.87      0.88      0.87     58008
#
#
# Accuracy Score (Training): 88.41%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19871          382
# Actual 1          950          475
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97     20253
#            1       0.55      0.33      0.42      1425
#
#     accuracy                           0.94     21678
#    macro avg       0.75      0.66      0.69     21678
# weighted avg       0.93      0.94      0.93     21678
#
#
# Accuracy Score (Test): 93.86%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD11NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD11NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD12NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49334         1543
# Actual 1         4966         2036
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     50877
#            1       0.57      0.29      0.38      7002
#
#     accuracy                           0.89     57879
#    macro avg       0.74      0.63      0.66     57879
# weighted avg       0.87      0.89      0.87     57879
#
#
# Accuracy Score (Training): 88.75%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19498          210
# Actual 1         1421          678
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     19708
#            1       0.76      0.32      0.45      2099
#
#     accuracy                           0.93     21807
#    macro avg       0.85      0.66      0.71     21807
# weighted avg       0.92      0.93      0.91     21807
#
#
# Accuracy Score (Test): 92.52%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD12NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD12NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD14NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        47731         2176
# Actual 1         4557         3580
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93     49907
#            1       0.62      0.44      0.52      8137
#
#     accuracy                           0.88     58044
#    macro avg       0.77      0.70      0.72     58044
# weighted avg       0.87      0.88      0.88     58044
#
#
# Accuracy Score (Training): 88.40%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19853          825
# Actual 1          592          372
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97     20678
#            1       0.31      0.39      0.34       964
#
#     accuracy                           0.93     21642
#    macro avg       0.64      0.67      0.65     21642
# weighted avg       0.94      0.93      0.94     21642
#
#
# Accuracy Score (Test): 93.45%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD14NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD14NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD15NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48468         2145
# Actual 1         4202         3229
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     50613
#            1       0.60      0.43      0.50      7431
#
#     accuracy                           0.89     58044
#    macro avg       0.76      0.70      0.72     58044
# weighted avg       0.88      0.89      0.88     58044
#
#
# Accuracy Score (Training): 89.07%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19470          502
# Actual 1         1350          320
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95     19972
#            1       0.39      0.19      0.26      1670
#
#     accuracy                           0.91     21642
#    macro avg       0.66      0.58      0.61     21642
# weighted avg       0.89      0.91      0.90     21642
#
#
# Accuracy Score (Test): 91.44%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD15NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD15NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD16NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51097         1166
# Actual 1         4060         1721
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     52263
#            1       0.60      0.30      0.40      5781
#
#     accuracy                           0.91     58044
#    macro avg       0.76      0.64      0.67     58044
# weighted avg       0.89      0.91      0.90     58044
#
#
# Accuracy Score (Training): 91.00%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17906          416
# Actual 1         2468          852
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93     18322
#            1       0.67      0.26      0.37      3320
#
#     accuracy                           0.87     21642
#    macro avg       0.78      0.62      0.65     21642
# weighted avg       0.85      0.87      0.84     21642
#
#
# Accuracy Score (Test): 86.67%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD16NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD16NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD18NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48339         1915
# Actual 1         4725         2948
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94     50254
#            1       0.61      0.38      0.47      7673
#
#     accuracy                           0.89     57927
#    macro avg       0.76      0.67      0.70     57927
# weighted avg       0.87      0.89      0.87     57927
#
#
# Accuracy Score (Training): 88.54%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19669          662
# Actual 1          804          624
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     20331
#            1       0.49      0.44      0.46      1428
#
#     accuracy                           0.93     21759
#    macro avg       0.72      0.70      0.71     21759
# weighted avg       0.93      0.93      0.93     21759
#
#
# Accuracy Score (Test): 93.26%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD18NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD18NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD21NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        47817         2073
# Actual 1         4966         3188
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93     49890
#            1       0.61      0.39      0.48      8154
#
#     accuracy                           0.88     58044
#    macro avg       0.76      0.67      0.70     58044
# weighted avg       0.86      0.88      0.87     58044
#
#
# Accuracy Score (Training): 87.87%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        20417          278
# Actual 1          749          198
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98     20695
#            1       0.42      0.21      0.28       947
#
#     accuracy                           0.95     21642
#    macro avg       0.69      0.60      0.63     21642
# weighted avg       0.94      0.95      0.94     21642
#
#
# Accuracy Score (Test): 95.25%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD21NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD21NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD23NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48323         1887
# Actual 1         4916         2861
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93     50210
#            1       0.60      0.37      0.46      7777
#
#     accuracy                           0.88     57987
#    macro avg       0.76      0.67      0.70     57987
# weighted avg       0.87      0.88      0.87     57987
#
#
# Accuracy Score (Training): 88.27%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        20178          197
# Actual 1         1029          295
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     20375
#            1       0.60      0.22      0.32      1324
#
#     accuracy                           0.94     21699
#    macro avg       0.78      0.61      0.65     21699
# weighted avg       0.93      0.94      0.93     21699
#
#
# Accuracy Score (Test): 94.35%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD23NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD23NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD10NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        47988         2074
# Actual 1         4799         3138
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93     50062
#            1       0.60      0.40      0.48      7937
#
#     accuracy                           0.88     57999
#    macro avg       0.76      0.68      0.71     57999
# weighted avg       0.87      0.88      0.87     57999
#
#
# Accuracy Score (Training): 88.15%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        20214          309
# Actual 1          902          262
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     20523
#            1       0.46      0.23      0.30      1164
#
#     accuracy                           0.94     21687
#    macro avg       0.71      0.61      0.64     21687
# weighted avg       0.93      0.94      0.94     21687
#
#
# Accuracy Score (Test): 94.42%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD10NF,DYAD24NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD10NF,DYAD24NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD11NF', 'DYAD12NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49951         1386
# Actual 1         4785         1721
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     51337
#            1       0.55      0.26      0.36      6506
#
#     accuracy                           0.89     57843
#    macro avg       0.73      0.62      0.65     57843
# weighted avg       0.87      0.89      0.88     57843
#
#
# Accuracy Score (Training): 89.33%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19015          233
# Actual 1         1719          876
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95     19248
#            1       0.79      0.34      0.47      2595
#
#     accuracy                           0.91     21843
#    macro avg       0.85      0.66      0.71     21843
# weighted avg       0.90      0.91      0.89     21843
#
#
# Accuracy Score (Test): 91.06%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD11NF,DYAD12NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD11NF,DYAD12NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD11NF', 'DYAD14NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48333         2034
# Actual 1         4410         3231
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     50367
#            1       0.61      0.42      0.50      7641
#
#     accuracy                           0.89     58008
#    macro avg       0.77      0.69      0.72     58008
# weighted avg       0.88      0.89      0.88     58008
#
#
# Accuracy Score (Training): 88.89%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19383          835
# Actual 1          851          609
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     20218
#            1       0.42      0.42      0.42      1460
#
#     accuracy                           0.92     21678
#    macro avg       0.69      0.69      0.69     21678
# weighted avg       0.92      0.92      0.92     21678
#
#
# Accuracy Score (Test): 92.22%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD11NF,DYAD14NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD11NF,DYAD14NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD11NF', 'DYAD15NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49069         2004
# Actual 1         4033         2902
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     51073
#            1       0.59      0.42      0.49      6935
#
#     accuracy                           0.90     58008
#    macro avg       0.76      0.69      0.72     58008
# weighted avg       0.88      0.90      0.89     58008
#
#
# Accuracy Score (Training): 89.59%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19006          506
# Actual 1         1614          552
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95     19512
#            1       0.52      0.25      0.34      2166
#
#     accuracy                           0.90     21678
#    macro avg       0.72      0.61      0.64     21678
# weighted avg       0.88      0.90      0.89     21678
#
#
# Accuracy Score (Test): 90.22%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD11NF,DYAD15NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD11NF,DYAD15NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD11NF', 'DYAD16NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51718         1005
# Actual 1         3861         1424
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96     52723
#            1       0.59      0.27      0.37      5285
#
#     accuracy                           0.92     58008
#    macro avg       0.76      0.63      0.66     58008
# weighted avg       0.90      0.92      0.90     58008
#
#
# Accuracy Score (Training): 91.61%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17425          437
# Actual 1         2782         1034
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92     17862
#            1       0.70      0.27      0.39      3816
#
#     accuracy                           0.85     21678
#    macro avg       0.78      0.62      0.65     21678
# weighted avg       0.83      0.85      0.82     21678
#
#
# Accuracy Score (Test): 85.15%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD11NF,DYAD16NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD11NF,DYAD16NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD11NF', 'DYAD18NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48984         1730
# Actual 1         4533         2644
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94     50714
#            1       0.60      0.37      0.46      7177
#
#     accuracy                           0.89     57891
#    macro avg       0.76      0.67      0.70     57891
# weighted avg       0.88      0.89      0.88     57891
#
#
# Accuracy Score (Training): 89.18%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19157          714
# Actual 1         1038          886
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     19871
#            1       0.55      0.46      0.50      1924
#
#     accuracy                           0.92     21795
#    macro avg       0.75      0.71      0.73     21795
# weighted avg       0.91      0.92      0.92     21795
#
#
# Accuracy Score (Test): 91.96%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD11NF,DYAD18NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD11NF,DYAD18NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD11NF', 'DYAD21NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48420         1930
# Actual 1         4793         2865
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94     50350
#            1       0.60      0.37      0.46      7658
#
#     accuracy                           0.88     58008
#    macro avg       0.75      0.67      0.70     58008
# weighted avg       0.87      0.88      0.87     58008
#
#
# Accuracy Score (Training): 88.41%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19937          298
# Actual 1         1011          432
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     20235
#            1       0.59      0.30      0.40      1443
#
#     accuracy                           0.94     21678
#    macro avg       0.77      0.64      0.68     21678
# weighted avg       0.93      0.94      0.93     21678
#
#
# Accuracy Score (Test): 93.96%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD11NF,DYAD21NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD11NF,DYAD21NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD11NF', 'DYAD23NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48943         1727
# Actual 1         4721         2560
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     50670
#            1       0.60      0.35      0.44      7281
#
#     accuracy                           0.89     57951
#    macro avg       0.75      0.66      0.69     57951
# weighted avg       0.87      0.89      0.88     57951
#
#
# Accuracy Score (Training): 88.87%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19683          232
# Actual 1         1339          481
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96     19915
#            1       0.67      0.26      0.38      1820
#
#     accuracy                           0.93     21735
#    macro avg       0.81      0.63      0.67     21735
# weighted avg       0.91      0.93      0.91     21735
#
#
# Accuracy Score (Test): 92.77%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD11NF,DYAD23NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD11NF,DYAD23NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD11NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48599         1923
# Actual 1         4626         2815
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94     50522
#            1       0.59      0.38      0.46      7441
#
#     accuracy                           0.89     57963
#    macro avg       0.75      0.67      0.70     57963
# weighted avg       0.87      0.89      0.88     57963
#
#
# Accuracy Score (Training): 88.70%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19721          342
# Actual 1         1167          493
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96     20063
#            1       0.59      0.30      0.40      1660
#
#     accuracy                           0.93     21723
#    macro avg       0.77      0.64      0.68     21723
# weighted avg       0.92      0.93      0.92     21723
#
#
# Accuracy Score (Test): 93.05%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD11NF,DYAD24NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD11NF,DYAD24NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD12NF', 'DYAD14NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49280         1632
# Actual 1         4638         2329
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     50912
#            1       0.59      0.33      0.43      6967
#
#     accuracy                           0.89     57879
#    macro avg       0.75      0.65      0.68     57879
# weighted avg       0.87      0.89      0.88     57879
#
#
# Accuracy Score (Training): 89.17%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19097          576
# Actual 1         1271          863
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95     19673
#            1       0.60      0.40      0.48      2134
#
#     accuracy                           0.92     21807
#    macro avg       0.77      0.69      0.72     21807
# weighted avg       0.90      0.92      0.91     21807
#
#
# Accuracy Score (Test): 91.53%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD12NF,DYAD14NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD12NF,DYAD14NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD12NF', 'DYAD15NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        50005         1613
# Actual 1         4210         2051
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94     51618
#            1       0.56      0.33      0.41      6261
#
#     accuracy                           0.90     57879
#    macro avg       0.74      0.65      0.68     57879
# weighted avg       0.88      0.90      0.89     57879
#
#
# Accuracy Score (Training): 89.94%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        18626          341
# Actual 1         2097          743
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94     18967
#            1       0.69      0.26      0.38      2840
#
#     accuracy                           0.89     21807
#    macro avg       0.79      0.62      0.66     21807
# weighted avg       0.87      0.89      0.87     21807
#
#
# Accuracy Score (Test): 88.82%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD12NF,DYAD15NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD12NF,DYAD15NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD12NF', 'DYAD16NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        52689          579
# Actual 1         3893          718
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     53268
#            1       0.55      0.16      0.24      4611
#
#     accuracy                           0.92     57879
#    macro avg       0.74      0.57      0.60     57879
# weighted avg       0.90      0.92      0.90     57879
#
#
# Accuracy Score (Training): 92.27%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17104          213
# Actual 1         3865          625
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.82      0.99      0.89     17317
#            1       0.75      0.14      0.23      4490
#
#     accuracy                           0.81     21807
#    macro avg       0.78      0.56      0.56     21807
# weighted avg       0.80      0.81      0.76     21807
#
#
# Accuracy Score (Test): 81.30%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD12NF,DYAD16NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD12NF,DYAD16NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD12NF', 'DYAD18NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49911         1348
# Actual 1         4729         1774
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     51259
#            1       0.57      0.27      0.37      6503
#
#     accuracy                           0.89     57762
#    macro avg       0.74      0.62      0.66     57762
# weighted avg       0.87      0.89      0.88     57762
#
#
# Accuracy Score (Training): 89.48%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        18933          393
# Actual 1         1678          920
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95     19326
#            1       0.70      0.35      0.47      2598
#
#     accuracy                           0.91     21924
#    macro avg       0.81      0.67      0.71     21924
# weighted avg       0.89      0.91      0.89     21924
#
#
# Accuracy Score (Test): 90.55%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD12NF,DYAD18NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD12NF,DYAD18NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD12NF', 'DYAD21NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49393         1502
# Actual 1         5001         1983
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     50895
#            1       0.57      0.28      0.38      6984
#
#     accuracy                           0.89     57879
#    macro avg       0.74      0.63      0.66     57879
# weighted avg       0.87      0.89      0.87     57879
#
#
# Accuracy Score (Training): 88.76%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19541          149
# Actual 1         1502          615
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     19690
#            1       0.80      0.29      0.43      2117
#
#     accuracy                           0.92     21807
#    macro avg       0.87      0.64      0.69     21807
# weighted avg       0.92      0.92      0.91     21807
#
#
# Accuracy Score (Test): 92.43%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD12NF,DYAD21NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD12NF,DYAD21NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD12NF', 'DYAD23NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49906         1309
# Actual 1         4903         1704
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     51215
#            1       0.57      0.26      0.35      6607
#
#     accuracy                           0.89     57822
#    macro avg       0.74      0.62      0.65     57822
# weighted avg       0.87      0.89      0.87     57822
#
#
# Accuracy Score (Training): 89.26%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19272           98
# Actual 1         1880          614
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95     19370
#            1       0.86      0.25      0.38      2494
#
#     accuracy                           0.91     21864
#    macro avg       0.89      0.62      0.67     21864
# weighted avg       0.91      0.91      0.89     21864
#
#
# Accuracy Score (Test): 90.95%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD12NF,DYAD23NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD12NF,DYAD23NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD12NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49577         1490
# Actual 1         4850         1917
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     51067
#            1       0.56      0.28      0.38      6767
#
#     accuracy                           0.89     57834
#    macro avg       0.74      0.63      0.66     57834
# weighted avg       0.87      0.89      0.87     57834
#
#
# Accuracy Score (Training): 89.04%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19344          174
# Actual 1         1670          664
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95     19518
#            1       0.79      0.28      0.42      2334
#
#     accuracy                           0.92     21852
#    macro avg       0.86      0.64      0.69     21852
# weighted avg       0.91      0.92      0.90     21852
#
#
# Accuracy Score (Test): 91.56%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD12NF,DYAD24NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD12NF,DYAD24NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD14NF', 'DYAD15NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48482         2166
# Actual 1         3801         3595
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94     50648
#            1       0.62      0.49      0.55      7396
#
#     accuracy                           0.90     58044
#    macro avg       0.78      0.72      0.74     58044
# weighted avg       0.89      0.90      0.89     58044
#
#
# Accuracy Score (Training): 89.72%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        18917         1020
# Actual 1         1247          458
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94     19937
#            1       0.31      0.27      0.29      1705
#
#     accuracy                           0.90     21642
#    macro avg       0.62      0.61      0.62     21642
# weighted avg       0.89      0.90      0.89     21642
#
#
# Accuracy Score (Test): 89.52%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD14NF,DYAD15NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD14NF,DYAD15NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD14NF', 'DYAD16NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51064         1234
# Actual 1         3759         1987
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     52298
#            1       0.62      0.35      0.44      5746
#
#     accuracy                           0.91     58044
#    macro avg       0.77      0.66      0.70     58044
# weighted avg       0.90      0.91      0.90     58044
#
#
# Accuracy Score (Training): 91.40%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17454          833
# Actual 1         2242         1113
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92     18287
#            1       0.57      0.33      0.42      3355
#
#     accuracy                           0.86     21642
#    macro avg       0.73      0.64      0.67     21642
# weighted avg       0.84      0.86      0.84     21642
#
#
# Accuracy Score (Test): 85.79%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD14NF,DYAD16NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD14NF,DYAD16NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD14NF', 'DYAD18NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48361         1928
# Actual 1         4376         3262
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     50289
#            1       0.63      0.43      0.51      7638
#
#     accuracy                           0.89     57927
#    macro avg       0.77      0.69      0.72     57927
# weighted avg       0.88      0.89      0.88     57927
#
#
# Accuracy Score (Training): 89.12%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19088         1208
# Actual 1          649          814
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95     20296
#            1       0.40      0.56      0.47      1463
#
#     accuracy                           0.91     21759
#    macro avg       0.68      0.75      0.71     21759
# weighted avg       0.93      0.91      0.92     21759
#
#
# Accuracy Score (Test): 91.47%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD14NF,DYAD18NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD14NF,DYAD18NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD14NF', 'DYAD21NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        47783         2142
# Actual 1         4623         3496
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93     49925
#            1       0.62      0.43      0.51      8119
#
#     accuracy                           0.88     58044
#    macro avg       0.77      0.69      0.72     58044
# weighted avg       0.87      0.88      0.87     58044
#
#
# Accuracy Score (Training): 88.35%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19948          712
# Actual 1          649          333
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97     20660
#            1       0.32      0.34      0.33       982
#
#     accuracy                           0.94     21642
#    macro avg       0.64      0.65      0.65     21642
# weighted avg       0.94      0.94      0.94     21642
#
#
# Accuracy Score (Test): 93.71%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD14NF,DYAD21NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD14NF,DYAD21NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD14NF', 'DYAD23NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48311         1934
# Actual 1         4626         3116
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94     50245
#            1       0.62      0.40      0.49      7742
#
#     accuracy                           0.89     57987
#    macro avg       0.76      0.68      0.71     57987
# weighted avg       0.87      0.89      0.88     57987
#
#
# Accuracy Score (Training): 88.69%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19751          589
# Actual 1          915          444
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     20340
#            1       0.43      0.33      0.37      1359
#
#     accuracy                           0.93     21699
#    macro avg       0.69      0.65      0.67     21699
# weighted avg       0.92      0.93      0.93     21699
#
#
# Accuracy Score (Test): 93.07%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD14NF,DYAD23NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD14NF,DYAD23NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD14NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        47952         2145
# Actual 1         4437         3465
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     50097
#            1       0.62      0.44      0.51      7902
#
#     accuracy                           0.89     57999
#    macro avg       0.77      0.70      0.72     57999
# weighted avg       0.87      0.89      0.88     57999
#
#
# Accuracy Score (Training): 88.65%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19736          752
# Actual 1          797          402
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     20488
#            1       0.35      0.34      0.34      1199
#
#     accuracy                           0.93     21687
#    macro avg       0.65      0.65      0.65     21687
# weighted avg       0.93      0.93      0.93     21687
#
#
# Accuracy Score (Test): 92.86%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD14NF,DYAD24NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD14NF,DYAD24NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD15NF', 'DYAD16NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51798         1206
# Actual 1         3351         1689
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96     53004
#            1       0.58      0.34      0.43      5040
#
#     accuracy                           0.92     58044
#    macro avg       0.76      0.66      0.69     58044
# weighted avg       0.91      0.92      0.91     58044
#
#
# Accuracy Score (Training): 92.15%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17028          553
# Actual 1         3123          938
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.90     17581
#            1       0.63      0.23      0.34      4061
#
#     accuracy                           0.83     21642
#    macro avg       0.74      0.60      0.62     21642
# weighted avg       0.80      0.83      0.80     21642
#
#
# Accuracy Score (Test): 83.01%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD15NF,DYAD16NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD15NF,DYAD16NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD15NF', 'DYAD18NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49052         1943
# Actual 1         3982         2950
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     50995
#            1       0.60      0.43      0.50      6932
#
#     accuracy                           0.90     57927
#    macro avg       0.76      0.69      0.72     57927
# weighted avg       0.89      0.90      0.89     57927
#
#
# Accuracy Score (Training): 89.77%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        18797          793
# Actual 1         1479          690
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94     19590
#            1       0.47      0.32      0.38      2169
#
#     accuracy                           0.90     21759
#    macro avg       0.70      0.64      0.66     21759
# weighted avg       0.88      0.90      0.89     21759
#
#
# Accuracy Score (Test): 89.56%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD15NF,DYAD18NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD15NF,DYAD18NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD15NF', 'DYAD21NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48543         2088
# Actual 1         4257         3156
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     50631
#            1       0.60      0.43      0.50      7413
#
#     accuracy                           0.89     58044
#    macro avg       0.76      0.69      0.72     58044
# weighted avg       0.88      0.89      0.88     58044
#
#
# Accuracy Score (Training): 89.07%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19544          410
# Actual 1         1413          275
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96     19954
#            1       0.40      0.16      0.23      1688
#
#     accuracy                           0.92     21642
#    macro avg       0.67      0.57      0.59     21642
# weighted avg       0.89      0.92      0.90     21642
#
#
# Accuracy Score (Test): 91.58%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD06NF,DYAD15NF,DYAD21NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD06NF,DYAD15NF,DYAD21NF.csv
# Processing with test video: ('DYAD06NF', 'DYAD15NF', 'DYAD23NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49034         1917
# Actual 1         4226         2810
#
# Classification Report (Training):
# ...
# Processing with test video: ('DYAD15NF', 'DYAD23NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49193         1874
# Actual 1         4142         2766
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     51067
#            1       0.60      0.40      0.48      6908
#
#     accuracy                           0.90     57975
#    macro avg       0.76      0.68      0.71     57975
# weighted avg       0.88      0.90      0.89     57975
#
#
# Accuracy Score (Training): 89.62%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19087          431
# Actual 1         1707          486
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95     19518
#            1       0.53      0.22      0.31      2193
#
#     accuracy                           0.90     21711
#    macro avg       0.72      0.60      0.63     21711
# weighted avg       0.88      0.90      0.88     21711
#
#
# Accuracy Score (Test): 90.15%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD15NF,DYAD23NF,DYAD24NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD15NF,DYAD23NF,DYAD24NF.csv
# Processing with test video: ('DYAD16NF', 'DYAD18NF', 'DYAD21NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51672          917
# Actual 1         3918         1453
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96     52589
#            1       0.61      0.27      0.38      5371
#
#     accuracy                           0.92     57960
#    macro avg       0.77      0.63      0.67     57960
# weighted avg       0.90      0.92      0.90     57960
#
#
# Accuracy Score (Training): 91.66%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17338          658
# Actual 1         2633         1097
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91     17996
#            1       0.63      0.29      0.40      3730
#
#     accuracy                           0.85     21726
#    macro avg       0.75      0.63      0.66     21726
# weighted avg       0.83      0.85      0.83     21726
#
#
# Accuracy Score (Test): 84.85%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD16NF,DYAD18NF,DYAD21NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD16NF,DYAD18NF,DYAD21NF.csv
# Processing with test video: ('DYAD16NF', 'DYAD18NF', 'DYAD23NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        52158          751
# Actual 1         3824         1170
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     52909
#            1       0.61      0.23      0.34      4994
#
#     accuracy                           0.92     57903
#    macro avg       0.77      0.61      0.65     57903
# weighted avg       0.90      0.92      0.90     57903
#
#
# Accuracy Score (Training): 92.10%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17178          498
# Actual 1         3102         1005
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91     17676
#            1       0.67      0.24      0.36      4107
#
#     accuracy                           0.83     21783
#    macro avg       0.76      0.61      0.63     21783
# weighted avg       0.81      0.83      0.80     21783
#
#
# Accuracy Score (Test): 83.47%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD16NF,DYAD18NF,DYAD23NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD16NF,DYAD18NF,DYAD23NF.csv
# Processing with test video: ('DYAD16NF', 'DYAD18NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51845          916
# Actual 1         3748         1406
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96     52761
#            1       0.61      0.27      0.38      5154
#
#     accuracy                           0.92     57915
#    macro avg       0.77      0.63      0.67     57915
# weighted avg       0.90      0.92      0.91     57915
#
#
# Accuracy Score (Training): 91.95%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17154          670
# Actual 1         2800         1147
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91     17824
#            1       0.63      0.29      0.40      3947
#
#     accuracy                           0.84     21771
#    macro avg       0.75      0.63      0.65     21771
# weighted avg       0.82      0.84      0.82     21771
#
#
# Accuracy Score (Test): 84.06%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD16NF,DYAD18NF,DYAD24NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD16NF,DYAD18NF,DYAD24NF.csv
# Processing with test video: ('DYAD16NF', 'DYAD21NF', 'DYAD23NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51641          904
# Actual 1         4080         1395
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     52545
#            1       0.61      0.25      0.36      5475
#
#     accuracy                           0.91     58020
#    macro avg       0.77      0.62      0.66     58020
# weighted avg       0.90      0.91      0.90     58020
#
#
# Accuracy Score (Training): 91.41%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17732          308
# Actual 1         2903          723
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92     18040
#            1       0.70      0.20      0.31      3626
#
#     accuracy                           0.85     21666
#    macro avg       0.78      0.59      0.61     21666
# weighted avg       0.83      0.85      0.82     21666
#
#
# Accuracy Score (Test): 85.18%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD16NF,DYAD21NF,DYAD23NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD16NF,DYAD21NF,DYAD23NF.csv
# Processing with test video: ('DYAD16NF', 'DYAD21NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51344         1053
# Actual 1         4025         1610
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     52397
#            1       0.60      0.29      0.39      5635
#
#     accuracy                           0.91     58032
#    macro avg       0.77      0.63      0.67     58032
# weighted avg       0.90      0.91      0.90     58032
#
#
# Accuracy Score (Training): 91.25%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17757          431
# Actual 1         2658          808
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92     18188
#            1       0.65      0.23      0.34      3466
#
#     accuracy                           0.86     21654
#    macro avg       0.76      0.60      0.63     21654
# weighted avg       0.83      0.86      0.83     21654
#
#
# Accuracy Score (Test): 85.73%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD16NF,DYAD21NF,DYAD24NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD16NF,DYAD21NF,DYAD24NF.csv
# Processing with test video: ('DYAD16NF', 'DYAD23NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        51871          846
# Actual 1         3923         1335
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96     52717
#            1       0.61      0.25      0.36      5258
#
#     accuracy                           0.92     57975
#    macro avg       0.77      0.62      0.66     57975
# weighted avg       0.90      0.92      0.90     57975
#
#
# Accuracy Score (Training): 91.77%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        17540          328
# Actual 1         3104          739
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91     17868
#            1       0.69      0.19      0.30      3843
#
#     accuracy                           0.84     21711
#    macro avg       0.77      0.59      0.61     21711
# weighted avg       0.82      0.84      0.80     21711
#
#
# Accuracy Score (Test): 84.19%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD16NF,DYAD23NF,DYAD24NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD16NF,DYAD23NF,DYAD24NF.csv
# Processing with test video: ('DYAD18NF', 'DYAD21NF', 'DYAD23NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48934         1602
# Actual 1         4811         2556
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     50536
#            1       0.61      0.35      0.44      7367
#
#     accuracy                           0.89     57903
#    macro avg       0.76      0.66      0.69     57903
# weighted avg       0.87      0.89      0.88     57903
#
#
# Accuracy Score (Training): 88.92%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19478          571
# Actual 1         1032          702
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96     20049
#            1       0.55      0.40      0.47      1734
#
#     accuracy                           0.93     21783
#    macro avg       0.75      0.69      0.71     21783
# weighted avg       0.92      0.93      0.92     21783
#
#
# Accuracy Score (Test): 92.64%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD18NF,DYAD21NF,DYAD23NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD18NF,DYAD21NF,DYAD23NF.csv
# Processing with test video: ('DYAD18NF', 'DYAD21NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48551         1837
# Actual 1         4661         2866
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94     50388
#            1       0.61      0.38      0.47      7527
#
#     accuracy                           0.89     57915
#    macro avg       0.76      0.67      0.70     57915
# weighted avg       0.87      0.89      0.88     57915
#
#
# Accuracy Score (Training): 88.78%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19469          728
# Actual 1          868          706
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     20197
#            1       0.49      0.45      0.47      1574
#
#     accuracy                           0.93     21771
#    macro avg       0.72      0.71      0.72     21771
# weighted avg       0.92      0.93      0.93     21771
#
#
# Accuracy Score (Test): 92.67%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD18NF,DYAD21NF,DYAD24NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD18NF,DYAD21NF,DYAD24NF.csv
# Processing with test video: ('DYAD18NF', 'DYAD23NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        49103         1605
# Actual 1         4638         2512
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     50708
#            1       0.61      0.35      0.45      7150
#
#     accuracy                           0.89     57858
#    macro avg       0.76      0.66      0.69     57858
# weighted avg       0.88      0.89      0.88     57858
#
#
# Accuracy Score (Training): 89.21%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19257          620
# Actual 1         1179          772
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96     19877
#            1       0.55      0.40      0.46      1951
#
#     accuracy                           0.92     21828
#    macro avg       0.75      0.68      0.71     21828
# weighted avg       0.91      0.92      0.91     21828
#
#
# Accuracy Score (Test): 91.76%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD18NF,DYAD23NF,DYAD24NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD18NF,DYAD23NF,DYAD24NF.csv
# Processing with test video: ('DYAD21NF', 'DYAD23NF', 'DYAD24NF')...
#
# Training Set Performance:
#
# Confusion Matrix (Training):
#           Predicted 0  Predicted 1
# Actual 0        48568         1776
# Actual 1         4861         2770
#
# Classification Report (Training):
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94     50344
#            1       0.61      0.36      0.45      7631
#
#     accuracy                           0.89     57975
#    macro avg       0.76      0.66      0.70     57975
# weighted avg       0.87      0.89      0.87     57975
#
#
# Accuracy Score (Training): 88.55%
#
# Test Set Performance:
#
# Confusion Matrix (Test):
#           Predicted 0  Predicted 1
# Actual 0        19988          253
# Actual 1         1120          350
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     20241
#            1       0.58      0.24      0.34      1470
#
#     accuracy                           0.94     21711
#    macro avg       0.76      0.61      0.65     21711
# weighted avg       0.92      0.94      0.92     21711
#
#
# Accuracy Score (Test): 93.68%
# Training dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/train_dataset_balanced_DYAD21NF,DYAD23NF,DYAD24NF.csv
# Test dataset for test video DYAD24NF saved to /Users/ruzenkakaldenbach/Desktop/test_dataset_balanced_DYAD21NF,DYAD23NF,DYAD24NF.csv
#
# Overall Performance:
# Average Training Accuracy: 89.94%
# Average Testing Accuracy: 89.29%
# Processing complete.
